# %% [markdown]
# # Breast Cancer Detection
# ## Project: Let's try to XXXX

# %% [markdown]
# TODO: here goes the project description, motivation, what exists already, ....

# %% [markdown]
# # Analysis
#
# ## Data Exploration
#
# TODO: What do you want to see on this data exploration? What are your assumptions?

# %%
# Import libraries
import numpy as np
import pandas as pd

print('Dependencies loaded successfully!')
# Out:
# Dependencies loaded successfully!

# %%
# Load test and train dataset
# Read imported data
dt_train = pd.read_csv("data/train.csv")
dt_test = pd.read_csv("data/test.csv")
print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
# print train data
dt_train.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    853612        11.84         18.70           77.93      440.6
# 1  85382601        17.02         23.98          112.80      899.3
# 2    854002        19.27         26.47          127.90     1162.0
# 3    854039        16.13         17.88          107.00      807.2
# 4    854253        16.74         21.59          110.10      869.5
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11090            0.1516          0.1218              0.05182
# 1          0.11970            0.1496          0.2417              0.12030
# 2          0.09401            0.1719          0.1657              0.07593
# 3        104.00000            0.1559          0.1354              0.07752
# 4          0.09610            0.1336          0.1348              0.06018
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %%
# print test data
dt_test.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    853612        11.84         18.70           77.93      440.6
# 1  85382601        17.02         23.98          112.80      899.3
# 2    854002        19.27         26.47          127.90     1162.0
# 3    854039        16.13         17.88          107.00      807.2
# 4    854253        16.74         21.59          110.10      869.5
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11090            0.1516          0.1218              0.05182
# 1          0.11970            0.1496          0.2417              0.12030
# 2          0.09401            0.1719          0.1657              0.07593
# 3        104.00000            0.1559          0.1354              0.07752
# 4          0.09610            0.1336          0.1348              0.06018
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %% [markdown]
# ### Exploratory Visualization
#
# TODO:  This section will explore the data visualization of the existing dataset and analyze the possible metrics that will be used to understand the solution. We will identify the relationship between each one of the features with the overall performance of the article. Within the following steps we will discuss:
#
# .... bla bla bla ....

# %%
dt_train.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  3.980000e+02   398.000000    398.000000      398.000000   398.000000
# mean   3.916943e+07   705.088518     19.176256       93.374221   673.997739
# std    1.476724e+08  2429.075022      4.389144       24.709093   362.508345
# min    8.670000e+03     8.950000     10.380000       43.790000   143.500000
# 25%    8.688372e+05    12.345000     15.925000       76.372500   431.325000
# 50%    9.125385e+05    13.920000     18.610000       87.450000   564.150000
# 75%    9.010259e+06    18.045000     21.567500      106.975000   812.200000
# max    9.113205e+08  9876.000000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       398.000000        398.000000      398.000000           398.000000
# mean          3.922253          4.796528        7.859466             2.059307
# ...

# %%
dt_test.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  1.710000e+02   171.000000    171.000000       171.00000   171.000000
# mean   9.895557e+06   710.688246     19.553567        88.69848   610.414035
# std    2.634465e+07  2440.094412      4.088946        23.05634   322.571348
# min    9.047000e+03     7.760000      9.710000        47.92000   181.000000
# 25%    8.729825e+05    11.865000     16.840000        72.75500   400.900000
# 50%    9.043570e+05    13.480000     19.340000        82.67000   514.300000
# 75%    9.233170e+05    16.530000     21.875000        99.66000   711.700000
# max    9.137670e+07  9904.000000     30.620000       182.10000  2250.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       171.000000        171.000000      171.000000           171.000000
# mean          5.195178          4.927817        6.627160             3.081349
# ...

# %% [markdown]
# TODO: What did we notice from this data?

# %% [markdown]
# ### Algorithms and Techniques
#
# TODO: What kind of algorithm will we use? Why? Explain it....

# %% [markdown]
# ### Benchmark
#
# TODO: What will be our benchmark?

# %% [markdown]
# ## Methodology

# %% [markdown]
# ## Data Preprocessing
#
# TODO: Data cleaning? Assigning classes to the dataset?  What is necessary to do before implement the models?

# %%
# implement the data preprocessing

# %% [markdown]
# TODO: any final consideration for the data processing? what did you notice?

# %% [markdown]
# ## Implementation
#
# ### Training and Testing Data Split
#
# TODO: explain train and test data (should we split or it is split already? What are we considering? How did we split?)

# %%
# implement data split (if necessary)

# %% [markdown]
# ### Training and Evaluating Models
#
# TODO: What did we try? How are we training the model?

# %% [markdown]
# ### Model Performance Metrics
#
# TODO: Run the model chosen and check the metrics

# %%
# TODO: implement

# %% [markdown]
# ## Refinement
#
# TODO: What were the problems? How did we evolve? Which parameters did we tested/changed?

# %%
# TODO: implement

# %% [markdown]
# # Results
#
# ## Model Evaluation and Validation
#
# TODO: which are the values that we reach? Show graphs, table, comparison, ...

# %% [markdown]
# # Conclusion
#
# ## Free-Form Visualization
#
# TODO: Show a conclusion with images of what was reached

# %%
# implement visualization

# %% [markdown]
# ## Reflection
#
# TODO: how was the project? what did we notice? what did we learn? What ...?

# %% [markdown]
# ## Improvement
#
# TODO: What else can be made?

# %% [markdown]
# # Reference
#
# TODO: which are the important references used?
#
# Example:
#
# [1] eMarketer Report. (2017). US Time Spent with Media: eMarketer’s Updated Estimates for 2017. Accessed 9 Aug. 2018. Available at: https://www.emarketer.com/Report/US-Time-Spent-with-Media-eMarketers-Updated-Estimates-2017/2002142
